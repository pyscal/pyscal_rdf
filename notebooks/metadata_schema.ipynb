# %%
from pyscal_rdf.schema import Sample
from pyscal_rdf import StructureGraph

# %%
g = StructureGraph()

# %%
struct = g.create.lattice.l12(element=['Ni', 'Al'])

# %%
schema = Sample()

# %%
schema.material.element_ratio = struct.composition

# %%
schema.model_dump()
# Out:
# /home/menon/miniconda3/envs/rdf-wf-6/lib/python3.10/site-packages/pydantic/main.py:308: UserWarning: Pydantic serializer warnings:
#   Expected `list[float]` but got `int` - serialized value may not be as expected
#   Expected `list[float]` but got `int` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# {'material': {'element_ratio': {'Al': 0.75, 'Ni': 0.25},
#   'crystal_structure': {'altname': None,
#    'spacegroup_symbol': None,
#    'spacegroup_number': None,
#    'unit_cell': {'bravais_lattice': None,
#     'lattice_parameter': 0,
#     'angle': [90.0, 90.0, 90.0]}},
#   'defect': {'grain_boundary': {'grain_boundary_type': None,
#     'sigma': 0,
#     'plane': 0,
#     'rotation_axis': 0,
#     'misorientation_angle': 0}}},
#  'simulation_cell': {'volume': 0,
#   'number_of_atoms': 0,
#   'length': [0, 0, 0],
#   'vector': None,
#   'angle': [0, 0, 0],
#   'vacancy_concentration': 0,
#   'number_of_vacancies': 0},
# ...
