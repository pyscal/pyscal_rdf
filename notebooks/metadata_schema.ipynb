# %%
from pyscal_rdf.schema import Sample
# Out:
# ---------------------------------------------------------------------------
# PydanticSchemaGenerationError             Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyscal_rdf.schema import Sample
#
# File ~/miniconda3/envs/rdf-wf-6/lib/python3.10/site-packages/pyscal_rdf/schema.py:63
#      60 	crystal_structure: Optional[CrystalStructure] = CrystalStructure()
#      61 	defect: Optional[Defect] = Defect()
# ---> 63 class Sample(BaseModel, title='Sample'):
#      64 	#material: Optional[Material] = Material()
#      65 	#simulation_cell: Optional[SimulationCell] = SimulationCell()
#      66 	calculated_property: [CalculatedProperty] = CalculatedProperty()
#      67 	#pass
#
# File ~/miniconda3/envs/rdf-wf-6/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:184, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, **kwargs)
# ...
